# %%
import pandas as pd

# %% [markdown]
# **functions of Pandas**
#
#     * .DataFrame() => to convert your data into a structured (tabular) form
#     * .read_csv() => to read an externam data
#     * .to_csv() => to save your data as a csv file

# %%
students = [["Amit" , 13 , 32 , "amit@abc.com"] , ["Ajay", 15, 35 , "ajay@abc.com"] , ["Ramesh" , 14 , 33 , "ramesh@abc.com"]]
print(students)
# Out:
# [['Amit', 13, 32, 'amit@abc.com'], ['Ajay', 15, 35, 'ajay@abc.com'], ['Ramesh', 14, 33, 'ramesh@abc.com']]

# %%
students_data = pd.DataFrame(students)
students_data.columns = ["Name" , "Age" , "Marks" , "Email"]
students_data
# Out:
#      Name  Age  Marks           Email
# 0    Amit   13     32    amit@abc.com
# 1    Ajay   15     35    ajay@abc.com
# 2  Ramesh   14     33  ramesh@abc.com

# %% [markdown]
# **read csv data from github**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bipulshahi/Dataset/refs/heads/main/imdb_1000.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
print(df.duration.mean())
# Out:
# 120.97957099080695

# %%
print(df.duration.mean())
# Out:
# 120.97957099080695

# %% [markdown]
# * data shape and size
# * data filter
# * unique values in a data column
# * statistical calculations of a data column

# %%
df.shape
# Out:
# (979, 6)

# %%
df.head(7)
# Out:
#    star_rating                           title content_rating    genre  \
# 0          9.3        The Shawshank Redemption              R    Crime
# 1          9.2                   The Godfather              R    Crime
# 2          9.1          The Godfather: Part II              R    Crime
# 3          9.0                 The Dark Knight          PG-13   Action
# 4          8.9                    Pulp Fiction              R    Crime
# 5          8.9                    12 Angry Men      NOT RATED    Drama
# 6          8.9  The Good, the Bad and the Ugly      NOT RATED  Western
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ...

# %%
(df.genre == 'Crime').sum()
# Out:
# np.int64(124)

# %%
df_crime = df[df.genre == 'Crime']
df_crime
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
(df.star_rating > 8.5).sum()
# Out:
# np.int64(40)

# %%
df_rating_more_then_8_5 = df[df.star_rating > 8.5]
df_rating_more_then_8_5
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.head(3)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
#Unique values in a data column
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
#Number of samples for each unique values
df.genre.value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
#text = "Arjun"
text = "JAI"

print('A' in text)
print(text[0] == 'A')
# Out:
# True
# False

# %%
#df.title.str.contains('A')

# %%
print('A' in 'The Shawshank Redemption')
print('A' in 'American History')
# Out:
# False
# True

# %%
def check_A(text):
    return 'A' in text

# %%
check_A('American History')
# Out:
# True

# %%
#use 'apply()' inbuilt function => to apply a user defined function

df[df.title.apply(check_A)]
# Out:
#      star_rating                    title content_rating      genre  duration  \
# 5            8.9             12 Angry Men      NOT RATED      Drama        96
# 30           8.6            Spirited Away             PG  Animation       125
# 34           8.6       American History X              R      Crime       119
# 37           8.6  Raiders of the Lost Ark             PG     Action       115
# 51           8.5           Apocalypse Now              R      Drama       153
# ..           ...                      ...            ...        ...       ...
# 940          7.4   Much Ado About Nothing          PG-13     Comedy       111
# 941          7.4         A Bridge Too Far             PG      Drama       175
# 942          7.4          Raising Arizona          PG-13     Comedy        94
# 949          7.4               Home Alone             PG     Comedy       103
# 969          7.4      Law Abiding Citizen              R      Crime       109
#
# ...

# %%
def check_first_A(text):
    return text[0] == 'A'

# %%
check_first_A("Arjun")
# Out:
# True

# %%
df[df.title.apply(check_first_A)]
# Out:
#      star_rating                      title content_rating      genre  \
# 34           8.6         American History X              R      Crime
# 51           8.5             Apocalypse Now              R      Drama
# 57           8.5                      Alien              R     Horror
# 67           8.4            American Beauty              R      Drama
# 70           8.4                     Amelie              R     Comedy
# ..           ...                        ...            ...        ...
# 869          7.5  A Nightmare on Elm Street              R     Horror
# 883          7.5      A History of Violence              R      Crime
# 923          7.5        Across the Universe          PG-13      Drama
# 938          7.4        Alice in Wonderland              G  Animation
# 941          7.4           A Bridge Too Far             PG      Drama
#
#      duration                                        actors_list
# ...

# %%
df[df.title.str.startswith('A')]
# Out:
#      star_rating                      title content_rating      genre  \
# 34           8.6         American History X              R      Crime
# 51           8.5             Apocalypse Now              R      Drama
# 57           8.5                      Alien              R     Horror
# 67           8.4            American Beauty              R      Drama
# 70           8.4                     Amelie              R     Comedy
# ..           ...                        ...            ...        ...
# 869          7.5  A Nightmare on Elm Street              R     Horror
# 883          7.5      A History of Violence              R      Crime
# 923          7.5        Across the Universe          PG-13      Drama
# 938          7.4        Alice in Wonderland              G  Animation
# 941          7.4           A Bridge Too Far             PG      Drama
#
#      duration                                        actors_list
# ...

# %%
user_input = input("Enter the 1st character of the movies").upper()
print(user_input)
df[df.title.str.startswith(user_input)]
# Out:
# Enter the 1st character of the movies d
# D
#      star_rating                                              title  \
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 59           8.5                                   Django Unchained
# 68           8.4                                           Das Boot
# 79           8.4                                   Double Indemnity
# 93           8.4                        Dilwale Dulhania Le Jayenge
# 109          8.3                                     Dil Chahta Hai
# 125          8.3                                           Downfall
# 138          8.3                                           Die Hard
# 161          8.2                                         Diabolique
# 171          8.2                                  Dial M for Murder
# 211          8.1                                         Departures
# 218          8.1                                       Donnie Darko
# ...

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
#Filter all the data samples belongs from 'Crime' or 'Comedy' or 'Action'

df[(df.genre == 'Crime') | (df.genre == 'Comedy') | (df.genre == 'Action')]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 969          7.4                              Law Abiding Citizen
# 971          7.4                               Death at a Funeral
# 974          7.4                                          Tootsie
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
df.head(3)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %% [markdown]
# * Average star_rating
# * Minimum star_rating
# * maximum star_rating
# * Movies with maximum rating
# * Movies with minimum rating

# %%
print(df.star_rating.mean())
print(df.star_rating.min())
print(df.star_rating.max())
# Out:
# 7.889785495403474
# 7.4
# 9.3

# %%
df[df.star_rating == df.star_rating.max()]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
